# %% [markdown]
# # Unet for Lumbar Spine Segmentation

# %% [markdown]
# ## Data preparation

# %%
import os
import hdf5storage
import matplotlib.pyplot as plt
import numpy as np

DEBUG_MODE = True
DATA_PATH='C:/Research/LumbarSpine/RealSegmentationData/'
H, W, D, C, O = 512, 512, 30, 1, 4
BATCH_SIZE = 3
NUM_EPOCHS = 100
LEARNING_RATE = 0.01
LR_SCHEDULER = 30

# %%
if DEBUG_MODE:
    MatData=hdf5storage.loadmat(DATA_PATH + 'SegData_P' + str(1)  +'.mat',
                            options=hdf5storage.Options(matlab_compatible=True))
    print (MatData.keys())
# Out:
# dict_keys(['BgSegMap', 'DSegMap', 'I', 'OtherSegMap', 'VSegMap'])

# %%
if DEBUG_MODE:
    x_data = MatData['I']
    y0_data, y1_data, y2_data, y3_data = MatData['DSegMap'], MatData['VSegMap'], \
                                     MatData['BgSegMap'], MatData['OtherSegMap']
    print(x_data.shape, type(x_data))
    print(y0_data.shape, y1_data.shape, y2_data.shape, y3_data.shape, type(y0_data))
# Out:
# (512, 512) <class 'numpy.ndarray'>
# (512, 512) (512, 512) (512, 512) (512, 512) <class 'numpy.ndarray'>

# %% [markdown]
# ### Initalize Pytorch Dataloader Class

# %%
import torch
from torch.utils.data import Dataset, DataLoader
    
class spineSegDataset(Dataset):
    def __init__(self, path):
        self.input_images = np.zeros((D, C, H, W))
        self.mask_images = np.zeros((D, O, H, W))
        self.__dataload(path)
        
    def __dataload(self, path):
        if not os.path.isdir(path):
            raise FileNotFoundErrore('Path is not a directory')
        
        for i in range(0, D):
            MatData=hdf5storage.loadmat(path + 'SegData_P' + str(i+1)  +'.mat',
                            options=hdf5storage.Options(matlab_compatible=True))
            for j in range(0, C):
                self.input_images[i, j] = MatData['I']
            channels = ('DSegMap', 'VSegMap', 'BgSegMap', 'OtherSegMap')
            for j in range(0, O):
                self.mask_images[i, j] = MatData[channels[j]]
    
    def __len__(self):
        return len(self.input_images)
    
    def __getitem__(self, idx):
        image = self.input_images[idx]
        mask = self.mask_images[idx]
        
        return [image, mask]

# %% [markdown]
# ### Unit Test for Dataloader

# %% [markdown]
# This part will test whether dataset is will wrapped together with dataloader.

# %%
UnitTrainset = spineSegDataset(path=DATA_PATH)
UnitTrainloader = DataLoader(dataset=UnitTrainset, batch_size=3, shuffle=True)
UnitPlotloader = DataLoader(dataset=UnitTrainset, batch_size=1, shuffle=True)
for image, mask in UnitTrainloader:
    print(type(image), type(mask))
    print(image.shape, mask.shape)
    break
# Out:
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([3, 1, 512, 512]) torch.Size([3, 4, 512, 512])

# %%
import torchvision.utils
    
for image, mask in UnitTrainloader:
    fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(15,15))
    axs[0].imshow(image.numpy()[0, 0], interpolation='none')
    axs[1].imshow(mask.numpy()[0, 0])
    axs[2].imshow(mask.numpy()[0, 1])
    axs[3].imshow(mask.numpy()[0, 2])
    axs[4].imshow(mask.numpy()[0, 3])
    break

# %% [markdown]
# ## Unet

# %% [markdown]
# ### Dataset Split

# %%
from torch.utils.data import random_split
from torch.utils.data import Dataset, DataLoader
import torch

torch.manual_seed(17)

spine_dataset = spineSegDataset(path=DATA_PATH)
spine_trainset, spine_validset, spine_testset = random_split(spine_dataset, lengths=[20, 5, 5])
spine_dataset = {
    'train': spine_trainset,
    'valid': spine_validset,
    'test': spine_testset
}
spine_loader = {
    'train': DataLoader(spine_trainset, batch_size=BATCH_SIZE, shuffle=True),
    'valid': DataLoader(spine_validset, batch_size=BATCH_SIZE, shuffle=True),
    'test': DataLoader(spine_validset, batch_size=1, shuffle=True)
}

# %% [markdown]
# ### Create Unet Model

# %%
from collections import OrderedDict

import torch
import torch.nn as nn

#### Parameters Reference for nn.Conv2d(in_channels, out_channels, kernel_size, padding)
class UNetBlock(nn.Module):
    def __init__(self, in_ch, out_ch, name, block_batch_norm=True):
        super(UNetBlock, self).__init__()
        self.block_batch_norm = block_batch_norm
        
        self.block = nn.Sequential(OrderedDict([
                        (name + "conv1", nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False)),
                        (name + "norm1", nn.BatchNorm2d(out_ch)),
                        (name + "relu1", nn.ReLU(inplace=True)),
                        (name + "conv2", nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False)),
                        (name + "norm2", nn.BatchNorm2d(out_ch)),
                        (name + "relu2", nn.ReLU(inplace=True))
        ]))
        
        self.block_wo_norm = nn.Sequential(OrderedDict([
                        (name + "conv1_wo", nn.Conv2d(in_ch, out_ch, 3, padding=1)),
                        (name + "relu1_wo", nn.ReLU(inplace=True)),
                        (name + "conv2_wo", nn.Conv2d(out_ch, out_ch, 3, padding=1)),
                        (name + "relu2_wo", nn.ReLU(inplace=True))
        ]))
        
    def forward(self, input):
        if self.block_batch_norm:
            return self.block(input)
        else:
            return self.block_wo_norm(input)
        

class UNet(nn.Module):

    def __init__(self, in_channels=1, out_channels=4, init_features=32):
        super(UNet, self).__init__()

        features = init_features
        self.encoder1 = UNetBlock(in_channels, features, name="enc1")
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder2 = UNetBlock(features, features*2, name="enc2")
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder3 = UNetBlock(features*2, features*4, name="enc3")
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder4 = UNetBlock(features*4, features*8, name="enc4")
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.bottleneck = UNetBlock(features*8, features*16, name="bottleneck")

        self.upconv4 = nn.ConvTranspose2d(
            features*16, features*8, kernel_size=2, stride=2
        )
        self.decoder4 = UNetBlock((features*8)*2, features*8, name="dec4")
        self.upconv3 = nn.ConvTranspose2d(
            features * 8, features * 4, kernel_size=2, stride=2
        )
        self.decoder3 = UNetBlock((features*4)*2, features*4, name="dec3")
        self.upconv2 = nn.ConvTranspose2d(
            features * 4, features * 2, kernel_size=2, stride=2
        )
        self.decoder2 = UNetBlock((features*2)*2, features*2, name="dec2")
        self.upconv1 = nn.ConvTranspose2d(
            features * 2, features, kernel_size=2, stride=2
        )
        self.decoder1 = UNetBlock(features*2, features, name="dec1")

        self.conv = nn.Conv2d(
            in_channels=features, out_channels=out_channels, kernel_size=1
        )

    def forward(self, x):
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.pool1(enc1))
        enc3 = self.encoder3(self.pool2(enc2))
        enc4 = self.encoder4(self.pool3(enc3))

        bottleneck = self.bottleneck(self.pool4(enc4))

        dec4 = self.upconv4(bottleneck)
        dec4 = torch.cat((dec4, enc4), dim=1)
        dec4 = self.decoder4(dec4)
        dec3 = self.upconv3(dec4)
        dec3 = torch.cat((dec3, enc3), dim=1)
        dec3 = self.decoder3(dec3)
        dec2 = self.upconv2(dec3)
        dec2 = torch.cat((dec2, enc2), dim=1)
        dec2 = self.decoder2(dec2)
        dec1 = self.upconv1(dec2)
        dec1 = torch.cat((dec1, enc1), dim=1)
        dec1 = self.decoder1(dec1)
        return torch.sigmoid(self.conv(dec1))

# %% [markdown]
# ### Model Summary

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = UNet()
model = model.to(device)

from torchsummary import summary
summary(model, input_size=(1, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 512, 512]             288
#        BatchNorm2d-2         [-1, 32, 512, 512]              64
#               ReLU-3         [-1, 32, 512, 512]               0
#             Conv2d-4         [-1, 32, 512, 512]           9,216
#        BatchNorm2d-5         [-1, 32, 512, 512]              64
#               ReLU-6         [-1, 32, 512, 512]               0
#          UNetBlock-7         [-1, 32, 512, 512]               0
#          MaxPool2d-8         [-1, 32, 256, 256]               0
#             Conv2d-9         [-1, 64, 256, 256]          18,432
#       BatchNorm2d-10         [-1, 64, 256, 256]             128
#              ReLU-11         [-1, 64, 256, 256]               0
#            Conv2d-12         [-1, 64, 256, 256]          36,864
#       BatchNorm2d-13         [-1, 64, 256, 256]             128
#              ReLU-14         [-1, 64, 256, 256]               0
#         UNetBlock-15         [-1, 64, 256, 256]               0
#         MaxPool2d-16         [-1, 64, 128, 128]               0
#            Conv2d-17        [-1, 128, 128, 128]          73,728
#       BatchNorm2d-18        [-1, 128, 128, 128]             256
#              ReLU-19        [-1, 128, 128, 128]               0
#            Conv2d-20        [-1, 128, 128, 128]         147,456
#       BatchNorm2d-21        [-1, 128, 128, 128]             256
#              ReLU-22        [-1, 128, 128, 128]               0
#         UNetBlock-23        [-1, 128, 128, 128]               0
#         MaxPool2d-24          [-1, 128, 64, 64]               0
#            Conv2d-25          [-1, 256, 64, 64]         294,912
#       BatchNorm2d-26          [-1, 256, 64, 64]             512
#              ReLU-27          [-1, 256, 64, 64]               0
#            Conv2d-28          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-29          [-1, 256, 64, 64]             512
#              ReLU-30          [-1, 256, 64, 64]               0
#         UNetBlock-31          [-1, 256, 64, 64]               0
#         MaxPool2d-32          [-1, 256, 32, 32]               0
#            Conv2d-33          [-1, 512, 32, 32]       1,179,648
#       BatchNorm2d-34          [-1, 512, 32, 32]           1,024
#              ReLU-35          [-1, 512, 32, 32]               0
#            Conv2d-36          [-1, 512, 32, 32]       2,359,296
#       BatchNorm2d-37          [-1, 512, 32, 32]           1,024
#              ReLU-38          [-1, 512, 32, 32]               0
#         UNetBlock-39          [-1, 512, 32, 32]               0
#   ConvTranspose2d-40          [-1, 256, 64, 64]         524,544
#            Conv2d-41          [-1, 256, 64, 64]       1,179,648
#       BatchNorm2d-42          [-1, 256, 64, 64]             512
#              ReLU-43          [-1, 256, 64, 64]               0
#            Conv2d-44          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-45          [-1, 256, 64, 64]             512
#              ReLU-46          [-1, 256, 64, 64]               0
#         UNetBlock-47          [-1, 256, 64, 64]               0
#   ConvTranspose2d-48        [-1, 128, 128, 128]         131,200
#            Conv2d-49        [-1, 128, 128, 128]         294,912
#       BatchNorm2d-50        [-1, 128, 128, 128]             256
#              ReLU-51        [-1, 128, 128, 128]               0
#            Conv2d-52        [-1, 128, 128, 128]         147,456
#       BatchNorm2d-53        [-1, 128, 128, 128]             256
#              ReLU-54        [-1, 128, 128, 128]               0
#         UNetBlock-55        [-1, 128, 128, 128]               0
#   ConvTranspose2d-56         [-1, 64, 256, 256]          32,832
#            Conv2d-57         [-1, 64, 256, 256]          73,728
#       BatchNorm2d-58         [-1, 64, 256, 256]             128
#              ReLU-59         [-1, 64, 256, 256]               0
#            Conv2d-60         [-1, 64, 256, 256]          36,864
#       BatchNorm2d-61         [-1, 64, 256, 256]             128
#              ReLU-62         [-1, 64, 256, 256]               0
#         UNetBlock-63         [-1, 64, 256, 256]               0
#   ConvTranspose2d-64         [-1, 32, 512, 512]           8,224
#            Conv2d-65         [-1, 32, 512, 512]          18,432
#       BatchNorm2d-66         [-1, 32, 512, 512]              64
#              ReLU-67         [-1, 32, 512, 512]               0
#            Conv2d-68         [-1, 32, 512, 512]           9,216
#       BatchNorm2d-69         [-1, 32, 512, 512]              64
#              ReLU-70         [-1, 32, 512, 512]               0
#         UNetBlock-71         [-1, 32, 512, 512]               0
#            Conv2d-72          [-1, 4, 512, 512]             132
# ================================================================
# Total params: 7,762,564
# Trainable params: 7,762,564
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.00
# Forward/backward pass size (MB): 1866.00
# Params size (MB): 29.61
# Estimated Total Size (MB): 1896.61
# ----------------------------------------------------------------

# %% [markdown]
# ### Define Loss

# %%
import torch.nn as nn


class CalcultedLoss(nn.Module):

    def __init__(self):
        super(CalcultedLoss, self).__init__()
        self.smooth = 1.0
        
    def _dice_loss(self, y_pred, y_true, metrics):
        y_pred = y_pred.contiguous()
        y_true = y_true.contiguous()       
        intersection = (y_pred * y_true).sum(dim=2).sum(dim=2)
        dice_loss = (1 - ((2. * intersection + self.smooth) / (y_pred.sum(dim=2).sum(dim=2) + y_true.sum(dim=2).sum(dim=2) + self.smooth)))
        dice_loss = dice_loss.mean()
        
        metrics['dice_loss'] += dice_loss.data.cpu().numpy()
        return dice_loss
    
    def _bce_loss(self, y_pred, y_true, metrics):
        bce_loss = nn.BCEWithLogitsLoss()
        bce_loss = bce_loss(y_pred, y_true)
        
        metrics['bce_loss'] += bce_loss.data.cpu().numpy()
        return bce_loss
        
    def _bce_w_dice_loss(self, y_pred, y_true, metrics):
        bce_weight = 0.5
        bce_loss = self._bce_loss(y_pred, y_true, metrics)
        dice_loss = self._dice_loss(y_pred, y_true, metrics)
        
        bce_w_dice_loss = bce_weight * bce_loss + (1. - bce_weight) * dice_loss
        metrics['bce_w_dice_loss'] += bce_w_dice_loss.data.cpu().numpy()
        
        return bce_w_dice_loss

    def forward(self, y_pred, y_true, metrics):
        assert y_pred.size() == y_true.size()
        # Single Dice Loss
#         dice_loss = self._dice_loss(y_pred, y_true, metrics)
#         loss = dice_loss
#         metrics['loss'] = metrics['dice_loss']
        
        # Combined BCE Loss with Dice Loss
        loss = self._bce_w_dice_loss(y_pred, y_true, metrics)
        metrics['loss'] = metrics['bce_w_dice_loss']
        
        return loss

# %% [markdown]
# ### Argument Defination

# %%
import argparse

def parserDefination():
    parser = argparse.ArgumentParser(description="U-Net for semantic segmentation")
    parser.add_argument(
        "--batch-size",
        type=int,
        default=BATCH_SIZE,
        help="input batch size for training",
    )
    parser.add_argument(
        "--epochs",
        type=int,
        default=NUM_EPOCHS,
        help="number of epochs to train",
    )
    parser.add_argument(
        "--lr",
        type=float,
        default=LEARNING_RATE,
        help="initial learning rate"
    )
    parser.add_argument(
        "--lr_scheduler",
        type=int,
        default=LR_SCHEDULER,
        help="initial learning rate scheduler"
    )
    parser.add_argument(
        "--device",
        type=str,
        default="cuda",
        help="device for training (default: cuda:0)",
    )
    parser.add_argument(
        "--log_folder",
        type=str,
        default="./SpineUNet_Logs",
        help="folder to save logs"
    )
    parser.add_argument(
        "--save_folder",
        type=str,
        default="./SpineUNet_Saves"
    )
    args = parser.parse_args(args=[])
    return args

# %% [markdown]
# ### Training Phase

# %%
import numpy as np
from collections import defaultdict
import torch
import torch.optim as optim
import copy
from torch.utils.tensorboard import SummaryWriter

def print_metrics(metrics, samples, phase):
    outputs = []
    for k in metrics.keys():
        outputs.append("{}: {:4f}".format(k, metrics[k] / samples))

    print("{}: {}".format(phase, ", ".join(outputs)))

def train_each_epoch(model,
                     optimizer,
                     cal_loss,
                     data_loader,
                     device,
                     epoch,
                     log_folder,
                     best_valid_loss,
                     best_model_wts):
    loss_train, loss_valid = [], []
    
    for phase in ['train', 'valid']:
        if phase == 'train':
            model.train()
        else:
            model.eval()
        
        metrics = defaultdict(float)
        samples = 0
        
        for i_batch, sample_batch in enumerate(data_loader[phase]):
            x, y_true = sample_batch
            x, y_true = x.float(), y_true.float()
            x, y_true = x.to(device), y_true.to(device)
            
            optimizer.zero_grad()
            
            # forward
            with torch.set_grad_enabled(phase == 'train'):
                y_pred = model(x)
                loss = cal_loss.forward(y_pred, y_true, metrics=metrics)
                
                if phase == 'valid':
                    loss_valid.append(loss.item())
                    
                # backward and optimize only in training phase
                if phase == 'train':
                    loss_train.append(loss.item())
                    loss.backward()
                    optimizer.step()
            samples += 1
        
        print_metrics(metrics, samples, phase)
        epoch_loss = metrics['loss'] / samples
        
        # tensorboard            
        if phase == 'train':
            writer = SummaryWriter(log_dir=log_folder)
            writer.add_scalar('Loss/train', np.mean(loss_train), epoch)
        else:
            writer = SummaryWriter(log_dir=log_folder)
            writer.add_scalar('Loss/valid', np.mean(loss_valid), epoch)
            if epoch_loss < best_valid_loss:
                print('saving best model')
                best_valid_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
    return best_valid_loss, best_model_wts

# %% [markdown]
# ### Main Phrase

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

def train_model(args):
    # makedir for log folder and save folder
    os.makedirs(args.log_folder, exist_ok=True)
    os.makedirs(args.save_folder, exist_ok=True)
    log_folder = args.log_folder
    
    # Ensure device for training
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    ## Ensure DataLoader and Dataset
    
    ############# REMINDER ################
    # This part is automatically computed in Jupyter Notebook
    # But take care when you'd like to reconstruct the whole architecture
    #######################################
    #     spine_dataset = spineSegDataset(path=DATA_PATH)
    #     spine_trainset, spine_validset, spine_testset = random_split(spine_dataset, lengths=[20, 5, 5])
    #     spine_dataset = {
    #         'train': spine_trainset,
    #         'valid': spine_validset,
    #         'test': spine_testset
    #     }
    #     spine_loader = {
    #         'train': DataLoader(spine_trainset, batch_size=BATCH_SIZE, shuffle=True),
    #         'valid': DataLoader(spine_validset, batch_size=BATCH_SIZE, shuffle=True),
    #         'test': DataLoader(spine_validset, batch_size=BATCH_SIZE, shuffle=True)
    #     }
    ############ END ###################
    
    # Initial Model
    model = UNet(in_channels=C, out_channels=O)
    model.to(device)
    
    # Initial Loss
    cal_loss = CalcultedLoss()
    best_valid_loss = float("inf")
    
    best_model_wts = copy.deepcopy(model.state_dict())
    
    # Initial Optimizer
    optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=args.lr)
    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=args.lr_scheduler, gamma=0.1)
    
    num_epochs = args.epochs
    
    for epoch in range(num_epochs):
        
        # Display Progress
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        best_valid_loss, best_model_wts = train_each_epoch(model=model,
                                                           optimizer=optimizer_ft,
                                                           cal_loss=cal_loss,
                                                           data_loader=spine_loader,
                                                           device=device,
                                                           epoch=epoch,
                                                           log_folder=log_folder,
                                                           best_valid_loss=best_valid_loss,
                                                           best_model_wts=best_model_wts)

        exp_lr_scheduler.step()
        
    return best_model_wts

# %% [markdown]
# ### Training Progess

# %%
args = parserDefination()
best_model_weights = train_model(args=args)
# Out:
# Epoch 0/99
# ----------
# train: bce_loss: 0.785827, dice_loss: 0.695381, bce_w_dice_loss: 0.740604, loss: 0.740604
# valid: bce_loss: 0.815607, dice_loss: 0.770735, bce_w_dice_loss: 0.793171, loss: 0.793171
# saving best model
# Epoch 1/99
# ----------
# train: bce_loss: 0.713946, dice_loss: 0.607825, bce_w_dice_loss: 0.660886, loss: 0.660886
# valid: bce_loss: 0.672470, dice_loss: 0.793571, bce_w_dice_loss: 0.733020, loss: 0.733020
# saving best model
# Epoch 2/99
# ----------
# train: bce_loss: 0.681883, dice_loss: 0.543243, bce_w_dice_loss: 0.612563, loss: 0.612563
# valid: bce_loss: 0.683210, dice_loss: 0.797491, bce_w_dice_loss: 0.740351, loss: 0.740351
# Epoch 3/99
# ----------
# train: bce_loss: 0.660836, dice_loss: 0.442811, bce_w_dice_loss: 0.551824, loss: 0.551824
# valid: bce_loss: 0.683769, dice_loss: 0.783558, bce_w_dice_loss: 0.733663, loss: 0.733663
# Epoch 4/99
# ----------
# train: bce_loss: 0.645954, dice_loss: 0.339452, bce_w_dice_loss: 0.492703, loss: 0.492703
# valid: bce_loss: 0.683271, dice_loss: 0.679232, bce_w_dice_loss: 0.681252, loss: 0.681252
# saving best model
# Epoch 5/99
# ----------
# train: bce_loss: 0.637890, dice_loss: 0.272407, bce_w_dice_loss: 0.455148, loss: 0.455148
# valid: bce_loss: 0.692899, dice_loss: 0.651017, bce_w_dice_loss: 0.671958, loss: 0.671958
# saving best model
# Epoch 6/99
# ----------
# train: bce_loss: 0.631417, dice_loss: 0.238387, bce_w_dice_loss: 0.434902, loss: 0.434902
# valid: bce_loss: 0.654283, dice_loss: 0.411322, bce_w_dice_loss: 0.532802, loss: 0.532802
# saving best model
# Epoch 7/99
# ----------
# train: bce_loss: 0.629064, dice_loss: 0.209298, bce_w_dice_loss: 0.419181, loss: 0.419181
# valid: bce_loss: 0.647095, dice_loss: 0.490174, bce_w_dice_loss: 0.568635, loss: 0.568635
# Epoch 8/99
# ----------
# train: bce_loss: 0.625318, dice_loss: 0.196092, bce_w_dice_loss: 0.410705, loss: 0.410705
# valid: bce_loss: 0.664637, dice_loss: 0.353303, bce_w_dice_loss: 0.508970, loss: 0.508970
# saving best model
# Epoch 9/99
# ----------
# train: bce_loss: 0.624691, dice_loss: 0.188792, bce_w_dice_loss: 0.406742, loss: 0.406742
# valid: bce_loss: 0.663735, dice_loss: 0.517870, bce_w_dice_loss: 0.590802, loss: 0.590802
# Epoch 10/99
# ----------
# train: bce_loss: 0.623487, dice_loss: 0.184047, bce_w_dice_loss: 0.403767, loss: 0.403767
# valid: bce_loss: 0.648904, dice_loss: 0.303730, bce_w_dice_loss: 0.476317, loss: 0.476317
# saving best model
# Epoch 11/99
# ----------
# train: bce_loss: 0.621447, dice_loss: 0.160288, bce_w_dice_loss: 0.390867, loss: 0.390867
# valid: bce_loss: 0.668803, dice_loss: 0.311247, bce_w_dice_loss: 0.490025, loss: 0.490025
# Epoch 12/99
# ----------
# train: bce_loss: 0.624487, dice_loss: 0.166924, bce_w_dice_loss: 0.395705, loss: 0.395705
# valid: bce_loss: 0.670673, dice_loss: 0.506891, bce_w_dice_loss: 0.588782, loss: 0.588782
# Epoch 13/99
# ----------
# train: bce_loss: 0.618489, dice_loss: 0.140743, bce_w_dice_loss: 0.379616, loss: 0.379616
# valid: bce_loss: 0.623280, dice_loss: 0.191081, bce_w_dice_loss: 0.407180, loss: 0.407180
# saving best model
# Epoch 14/99
# ----------
# train: bce_loss: 0.617168, dice_loss: 0.136953, bce_w_dice_loss: 0.377061, loss: 0.377061
# valid: bce_loss: 0.639059, dice_loss: 0.219693, bce_w_dice_loss: 0.429376, loss: 0.429376
# Epoch 15/99
# ----------
# train: bce_loss: 0.617880, dice_loss: 0.131317, bce_w_dice_loss: 0.374598, loss: 0.374598
# valid: bce_loss: 0.720270, dice_loss: 0.547969, bce_w_dice_loss: 0.634119, loss: 0.634119
# Epoch 16/99
# ----------
# train: bce_loss: 0.619631, dice_loss: 0.140043, bce_w_dice_loss: 0.379837, loss: 0.379837
# valid: bce_loss: 0.659371, dice_loss: 0.340027, bce_w_dice_loss: 0.499699, loss: 0.499699
# Epoch 17/99
# ----------
# train: bce_loss: 0.618074, dice_loss: 0.127109, bce_w_dice_loss: 0.372592, loss: 0.372592
# valid: bce_loss: 0.624765, dice_loss: 0.177004, bce_w_dice_loss: 0.400884, loss: 0.400884
# saving best model
# Epoch 18/99
# ----------
# train: bce_loss: 0.615282, dice_loss: 0.113585, bce_w_dice_loss: 0.364434, loss: 0.364434
# valid: bce_loss: 0.620886, dice_loss: 0.211929, bce_w_dice_loss: 0.416407, loss: 0.416407
# Epoch 19/99
# ----------
# train: bce_loss: 0.614145, dice_loss: 0.106529, bce_w_dice_loss: 0.360337, loss: 0.360337
# valid: bce_loss: 0.625258, dice_loss: 0.386348, bce_w_dice_loss: 0.505803, loss: 0.505803
# Epoch 20/99
# ----------
# train: bce_loss: 0.613995, dice_loss: 0.104647, bce_w_dice_loss: 0.359321, loss: 0.359321
# valid: bce_loss: 0.620053, dice_loss: 0.227072, bce_w_dice_loss: 0.423562, loss: 0.423562
# Epoch 21/99
# ----------
# train: bce_loss: 0.613011, dice_loss: 0.097579, bce_w_dice_loss: 0.355295, loss: 0.355295
# valid: bce_loss: 0.623576, dice_loss: 0.229018, bce_w_dice_loss: 0.426297, loss: 0.426297
# Epoch 22/99
# ----------
# train: bce_loss: 0.612222, dice_loss: 0.093436, bce_w_dice_loss: 0.352829, loss: 0.352829
# valid: bce_loss: 0.624619, dice_loss: 0.304813, bce_w_dice_loss: 0.464716, loss: 0.464716
# Epoch 23/99
# ----------
# train: bce_loss: 0.612796, dice_loss: 0.094762, bce_w_dice_loss: 0.353779, loss: 0.353779
# valid: bce_loss: 0.625584, dice_loss: 0.252766, bce_w_dice_loss: 0.439175, loss: 0.439175
# Epoch 24/99
# ----------
# train: bce_loss: 0.612228, dice_loss: 0.093444, bce_w_dice_loss: 0.352836, loss: 0.352836
# valid: bce_loss: 0.628025, dice_loss: 0.358380, bce_w_dice_loss: 0.493202, loss: 0.493202
# Epoch 25/99
# ----------
# train: bce_loss: 0.612047, dice_loss: 0.090570, bce_w_dice_loss: 0.351308, loss: 0.351308
# valid: bce_loss: 0.620124, dice_loss: 0.171107, bce_w_dice_loss: 0.395616, loss: 0.395616
# saving best model
# Epoch 26/99
# ----------
# train: bce_loss: 0.611164, dice_loss: 0.083711, bce_w_dice_loss: 0.347437, loss: 0.347437
# valid: bce_loss: 0.620693, dice_loss: 0.143298, bce_w_dice_loss: 0.381995, loss: 0.381995
# saving best model
# Epoch 27/99
# ----------
# train: bce_loss: 0.611052, dice_loss: 0.076960, bce_w_dice_loss: 0.344006, loss: 0.344006
# valid: bce_loss: 0.624669, dice_loss: 0.287333, bce_w_dice_loss: 0.456001, loss: 0.456001
# Epoch 28/99
# ----------
# train: bce_loss: 0.610887, dice_loss: 0.083040, bce_w_dice_loss: 0.346964, loss: 0.346964
# valid: bce_loss: 0.628215, dice_loss: 0.248810, bce_w_dice_loss: 0.438512, loss: 0.438512
# Epoch 29/99
# ----------
# train: bce_loss: 0.610667, dice_loss: 0.077473, bce_w_dice_loss: 0.344070, loss: 0.344070
# valid: bce_loss: 0.626137, dice_loss: 0.223049, bce_w_dice_loss: 0.424593, loss: 0.424593
# Epoch 30/99
# ----------
# train: bce_loss: 0.610098, dice_loss: 0.073199, bce_w_dice_loss: 0.341649, loss: 0.341649
# valid: bce_loss: 0.620511, dice_loss: 0.192118, bce_w_dice_loss: 0.406315, loss: 0.406315
# Epoch 31/99
# ----------
# train: bce_loss: 0.609300, dice_loss: 0.065897, bce_w_dice_loss: 0.337599, loss: 0.337599
# valid: bce_loss: 0.618607, dice_loss: 0.170673, bce_w_dice_loss: 0.394640, loss: 0.394640
# Epoch 32/99
# ----------
# train: bce_loss: 0.608930, dice_loss: 0.063670, bce_w_dice_loss: 0.336300, loss: 0.336300
# valid: bce_loss: 0.618555, dice_loss: 0.166772, bce_w_dice_loss: 0.392663, loss: 0.392663
# Epoch 33/99
# ----------
# train: bce_loss: 0.608679, dice_loss: 0.061660, bce_w_dice_loss: 0.335169, loss: 0.335169
# valid: bce_loss: 0.618253, dice_loss: 0.154281, bce_w_dice_loss: 0.386267, loss: 0.386267
# Epoch 34/99
# ----------
# train: bce_loss: 0.608681, dice_loss: 0.062047, bce_w_dice_loss: 0.335364, loss: 0.335364
# valid: bce_loss: 0.616826, dice_loss: 0.136594, bce_w_dice_loss: 0.376710, loss: 0.376710
# saving best model
# Epoch 35/99
# ----------
# train: bce_loss: 0.608555, dice_loss: 0.060738, bce_w_dice_loss: 0.334647, loss: 0.334647
# valid: bce_loss: 0.617282, dice_loss: 0.152588, bce_w_dice_loss: 0.384935, loss: 0.384935
# Epoch 36/99
# ----------
# train: bce_loss: 0.608291, dice_loss: 0.059010, bce_w_dice_loss: 0.333651, loss: 0.333651
# valid: bce_loss: 0.618772, dice_loss: 0.176404, bce_w_dice_loss: 0.397588, loss: 0.397588
# Epoch 37/99
# ----------
# train: bce_loss: 0.608431, dice_loss: 0.059576, bce_w_dice_loss: 0.334004, loss: 0.334004
# valid: bce_loss: 0.617178, dice_loss: 0.151053, bce_w_dice_loss: 0.384116, loss: 0.384116
# Epoch 38/99
# ----------
# train: bce_loss: 0.608285, dice_loss: 0.057699, bce_w_dice_loss: 0.332992, loss: 0.332992
# valid: bce_loss: 0.618466, dice_loss: 0.167288, bce_w_dice_loss: 0.392877, loss: 0.392877
# Epoch 39/99
# ----------
# train: bce_loss: 0.607903, dice_loss: 0.056444, bce_w_dice_loss: 0.332174, loss: 0.332174
# valid: bce_loss: 0.618015, dice_loss: 0.162077, bce_w_dice_loss: 0.390046, loss: 0.390046
# Epoch 40/99
# ----------
# train: bce_loss: 0.607923, dice_loss: 0.056964, bce_w_dice_loss: 0.332444, loss: 0.332444
# valid: bce_loss: 0.618190, dice_loss: 0.171679, bce_w_dice_loss: 0.394935, loss: 0.394935
# Epoch 41/99
# ----------
# train: bce_loss: 0.607939, dice_loss: 0.057031, bce_w_dice_loss: 0.332485, loss: 0.332485
# valid: bce_loss: 0.616091, dice_loss: 0.138550, bce_w_dice_loss: 0.377321, loss: 0.377321
# Epoch 42/99
# ----------
# train: bce_loss: 0.607647, dice_loss: 0.055586, bce_w_dice_loss: 0.331616, loss: 0.331616
# valid: bce_loss: 0.616875, dice_loss: 0.165719, bce_w_dice_loss: 0.391297, loss: 0.391297
# Epoch 43/99
# ----------
# train: bce_loss: 0.607363, dice_loss: 0.054460, bce_w_dice_loss: 0.330912, loss: 0.330912
# valid: bce_loss: 0.618858, dice_loss: 0.196146, bce_w_dice_loss: 0.407502, loss: 0.407502
# Epoch 44/99
# ----------
# train: bce_loss: 0.607428, dice_loss: 0.054610, bce_w_dice_loss: 0.331019, loss: 0.331019
# valid: bce_loss: 0.616608, dice_loss: 0.160225, bce_w_dice_loss: 0.388417, loss: 0.388417
# Epoch 45/99
# ----------
# train: bce_loss: 0.606774, dice_loss: 0.052189, bce_w_dice_loss: 0.329482, loss: 0.329482
# valid: bce_loss: 0.616281, dice_loss: 0.157306, bce_w_dice_loss: 0.386793, loss: 0.386793
# Epoch 46/99
# ----------
# train: bce_loss: 0.606641, dice_loss: 0.052303, bce_w_dice_loss: 0.329472, loss: 0.329472
# valid: bce_loss: 0.615214, dice_loss: 0.128084, bce_w_dice_loss: 0.371649, loss: 0.371649
# saving best model
# Epoch 47/99
# ----------
# train: bce_loss: 0.606474, dice_loss: 0.051107, bce_w_dice_loss: 0.328791, loss: 0.328791
# valid: bce_loss: 0.617900, dice_loss: 0.183031, bce_w_dice_loss: 0.400466, loss: 0.400466
# Epoch 48/99
# ----------
# train: bce_loss: 0.606525, dice_loss: 0.051043, bce_w_dice_loss: 0.328784, loss: 0.328784
# valid: bce_loss: 0.617468, dice_loss: 0.166084, bce_w_dice_loss: 0.391776, loss: 0.391776
# Epoch 49/99
# ----------
# train: bce_loss: 0.606466, dice_loss: 0.051409, bce_w_dice_loss: 0.328937, loss: 0.328937
# valid: bce_loss: 0.615444, dice_loss: 0.144426, bce_w_dice_loss: 0.379935, loss: 0.379935
# Epoch 50/99
# ----------
# train: bce_loss: 0.606311, dice_loss: 0.049624, bce_w_dice_loss: 0.327967, loss: 0.327967
# valid: bce_loss: 0.615380, dice_loss: 0.147331, bce_w_dice_loss: 0.381355, loss: 0.381355
# Epoch 51/99
# ----------
# train: bce_loss: 0.606124, dice_loss: 0.048670, bce_w_dice_loss: 0.327397, loss: 0.327397
# valid: bce_loss: 0.614821, dice_loss: 0.137073, bce_w_dice_loss: 0.375947, loss: 0.375947
# Epoch 52/99
# ----------
# train: bce_loss: 0.606076, dice_loss: 0.048896, bce_w_dice_loss: 0.327486, loss: 0.327486
# valid: bce_loss: 0.615408, dice_loss: 0.149090, bce_w_dice_loss: 0.382249, loss: 0.382249
# Epoch 53/99
# ----------
# train: bce_loss: 0.605862, dice_loss: 0.048002, bce_w_dice_loss: 0.326932, loss: 0.326932
# valid: bce_loss: 0.617511, dice_loss: 0.186172, bce_w_dice_loss: 0.401842, loss: 0.401842
# Epoch 54/99
# ----------
# train: bce_loss: 0.605694, dice_loss: 0.047190, bce_w_dice_loss: 0.326442, loss: 0.326442
# valid: bce_loss: 0.615009, dice_loss: 0.154035, bce_w_dice_loss: 0.384522, loss: 0.384522
# Epoch 55/99
# ----------
# train: bce_loss: 0.605617, dice_loss: 0.046333, bce_w_dice_loss: 0.325975, loss: 0.325975
# valid: bce_loss: 0.616103, dice_loss: 0.158047, bce_w_dice_loss: 0.387075, loss: 0.387075
# Epoch 56/99
# ----------
# train: bce_loss: 0.605740, dice_loss: 0.046948, bce_w_dice_loss: 0.326344, loss: 0.326344
# valid: bce_loss: 0.615818, dice_loss: 0.149378, bce_w_dice_loss: 0.382598, loss: 0.382598
# Epoch 57/99
# ----------
# train: bce_loss: 0.605608, dice_loss: 0.046463, bce_w_dice_loss: 0.326036, loss: 0.326036
# valid: bce_loss: 0.615571, dice_loss: 0.128514, bce_w_dice_loss: 0.372043, loss: 0.372043
# Epoch 58/99
# ----------
# train: bce_loss: 0.605509, dice_loss: 0.046506, bce_w_dice_loss: 0.326007, loss: 0.326007
# valid: bce_loss: 0.614325, dice_loss: 0.135293, bce_w_dice_loss: 0.374809, loss: 0.374809
# Epoch 59/99
# ----------
# train: bce_loss: 0.605202, dice_loss: 0.044790, bce_w_dice_loss: 0.324996, loss: 0.324996
# valid: bce_loss: 0.614826, dice_loss: 0.148695, bce_w_dice_loss: 0.381761, loss: 0.381761
# Epoch 60/99
# ----------
# train: bce_loss: 0.605146, dice_loss: 0.043543, bce_w_dice_loss: 0.324344, loss: 0.324344
# valid: bce_loss: 0.614158, dice_loss: 0.135370, bce_w_dice_loss: 0.374764, loss: 0.374764
# Epoch 61/99
# ----------
# train: bce_loss: 0.605331, dice_loss: 0.044350, bce_w_dice_loss: 0.324841, loss: 0.324841
# valid: bce_loss: 0.614974, dice_loss: 0.143337, bce_w_dice_loss: 0.379156, loss: 0.379156
# Epoch 62/99
# ----------
# train: bce_loss: 0.605142, dice_loss: 0.043387, bce_w_dice_loss: 0.324264, loss: 0.324264
# valid: bce_loss: 0.614790, dice_loss: 0.144910, bce_w_dice_loss: 0.379850, loss: 0.379850
# Epoch 63/99
# ----------
# train: bce_loss: 0.605069, dice_loss: 0.042701, bce_w_dice_loss: 0.323885, loss: 0.323885
# valid: bce_loss: 0.614713, dice_loss: 0.142392, bce_w_dice_loss: 0.378552, loss: 0.378552
# Epoch 64/99
# ----------
# train: bce_loss: 0.605177, dice_loss: 0.044393, bce_w_dice_loss: 0.324785, loss: 0.324785
# valid: bce_loss: 0.614572, dice_loss: 0.136772, bce_w_dice_loss: 0.375672, loss: 0.375672
# Epoch 65/99
# ----------
# train: bce_loss: 0.604916, dice_loss: 0.042757, bce_w_dice_loss: 0.323837, loss: 0.323837
# valid: bce_loss: 0.613380, dice_loss: 0.120949, bce_w_dice_loss: 0.367164, loss: 0.367164
# saving best model
# Epoch 66/99
# ----------
# train: bce_loss: 0.605027, dice_loss: 0.043445, bce_w_dice_loss: 0.324236, loss: 0.324236
# valid: bce_loss: 0.614438, dice_loss: 0.137750, bce_w_dice_loss: 0.376094, loss: 0.376094
# Epoch 67/99
# ----------
# train: bce_loss: 0.604992, dice_loss: 0.043170, bce_w_dice_loss: 0.324081, loss: 0.324081
# valid: bce_loss: 0.614667, dice_loss: 0.136895, bce_w_dice_loss: 0.375781, loss: 0.375781
# Epoch 68/99
# ----------
# train: bce_loss: 0.604936, dice_loss: 0.043432, bce_w_dice_loss: 0.324184, loss: 0.324184
# valid: bce_loss: 0.614494, dice_loss: 0.130891, bce_w_dice_loss: 0.372693, loss: 0.372693
# Epoch 69/99
# ----------
# train: bce_loss: 0.604939, dice_loss: 0.043546, bce_w_dice_loss: 0.324242, loss: 0.324242
# valid: bce_loss: 0.613272, dice_loss: 0.121834, bce_w_dice_loss: 0.367553, loss: 0.367553
# Epoch 70/99
# ----------
# train: bce_loss: 0.604986, dice_loss: 0.043483, bce_w_dice_loss: 0.324235, loss: 0.324235
# valid: bce_loss: 0.614729, dice_loss: 0.139512, bce_w_dice_loss: 0.377120, loss: 0.377120
# Epoch 71/99
# ----------
# train: bce_loss: 0.605002, dice_loss: 0.042930, bce_w_dice_loss: 0.323966, loss: 0.323966
# valid: bce_loss: 0.613430, dice_loss: 0.126024, bce_w_dice_loss: 0.369727, loss: 0.369727
# Epoch 72/99
# ----------
# train: bce_loss: 0.604843, dice_loss: 0.043313, bce_w_dice_loss: 0.324078, loss: 0.324078
# valid: bce_loss: 0.614834, dice_loss: 0.146927, bce_w_dice_loss: 0.380881, loss: 0.380881
# Epoch 73/99
# ----------
# train: bce_loss: 0.604710, dice_loss: 0.041869, bce_w_dice_loss: 0.323290, loss: 0.323290
# valid: bce_loss: 0.613480, dice_loss: 0.126810, bce_w_dice_loss: 0.370145, loss: 0.370145
# Epoch 74/99
# ----------
# train: bce_loss: 0.604982, dice_loss: 0.043151, bce_w_dice_loss: 0.324067, loss: 0.324067
# valid: bce_loss: 0.613411, dice_loss: 0.124168, bce_w_dice_loss: 0.368789, loss: 0.368789
# Epoch 75/99
# ----------
# train: bce_loss: 0.604818, dice_loss: 0.041922, bce_w_dice_loss: 0.323370, loss: 0.323370
# valid: bce_loss: 0.613517, dice_loss: 0.121220, bce_w_dice_loss: 0.367369, loss: 0.367369
# Epoch 76/99
# ----------
# train: bce_loss: 0.604751, dice_loss: 0.042102, bce_w_dice_loss: 0.323426, loss: 0.323426
# valid: bce_loss: 0.613496, dice_loss: 0.120776, bce_w_dice_loss: 0.367136, loss: 0.367136
# saving best model
# Epoch 77/99
# ----------
# train: bce_loss: 0.604655, dice_loss: 0.041750, bce_w_dice_loss: 0.323202, loss: 0.323202
# valid: bce_loss: 0.613444, dice_loss: 0.120073, bce_w_dice_loss: 0.366759, loss: 0.366759
# saving best model
# Epoch 78/99
# ----------
# train: bce_loss: 0.604728, dice_loss: 0.041767, bce_w_dice_loss: 0.323247, loss: 0.323247
# valid: bce_loss: 0.614561, dice_loss: 0.136294, bce_w_dice_loss: 0.375427, loss: 0.375427
# Epoch 79/99
# ----------
# train: bce_loss: 0.604769, dice_loss: 0.041730, bce_w_dice_loss: 0.323249, loss: 0.323249
# valid: bce_loss: 0.614703, dice_loss: 0.140478, bce_w_dice_loss: 0.377590, loss: 0.377590
# Epoch 80/99
# ----------
# train: bce_loss: 0.604776, dice_loss: 0.042809, bce_w_dice_loss: 0.323792, loss: 0.323792
# valid: bce_loss: 0.613371, dice_loss: 0.124726, bce_w_dice_loss: 0.369049, loss: 0.369049
# Epoch 81/99
# ----------
# train: bce_loss: 0.604815, dice_loss: 0.042120, bce_w_dice_loss: 0.323467, loss: 0.323467
# valid: bce_loss: 0.614405, dice_loss: 0.133267, bce_w_dice_loss: 0.373836, loss: 0.373836
# Epoch 82/99
# ----------
# train: bce_loss: 0.604832, dice_loss: 0.042245, bce_w_dice_loss: 0.323539, loss: 0.323539
# valid: bce_loss: 0.614381, dice_loss: 0.132121, bce_w_dice_loss: 0.373251, loss: 0.373251
# Epoch 83/99
# ----------
# train: bce_loss: 0.604739, dice_loss: 0.041920, bce_w_dice_loss: 0.323330, loss: 0.323330
# valid: bce_loss: 0.613355, dice_loss: 0.119592, bce_w_dice_loss: 0.366474, loss: 0.366474
# saving best model
# Epoch 84/99
# ----------
# train: bce_loss: 0.604844, dice_loss: 0.042332, bce_w_dice_loss: 0.323588, loss: 0.323588
# valid: bce_loss: 0.613132, dice_loss: 0.121342, bce_w_dice_loss: 0.367237, loss: 0.367237
# Epoch 85/99
# ----------
# train: bce_loss: 0.604587, dice_loss: 0.041935, bce_w_dice_loss: 0.323261, loss: 0.323261
# valid: bce_loss: 0.614781, dice_loss: 0.143126, bce_w_dice_loss: 0.378954, loss: 0.378954
# Epoch 86/99
# ----------
# train: bce_loss: 0.604830, dice_loss: 0.042619, bce_w_dice_loss: 0.323725, loss: 0.323725
# valid: bce_loss: 0.614724, dice_loss: 0.141445, bce_w_dice_loss: 0.378085, loss: 0.378085
# Epoch 87/99
# ----------
# train: bce_loss: 0.604703, dice_loss: 0.041191, bce_w_dice_loss: 0.322947, loss: 0.322947
# valid: bce_loss: 0.613098, dice_loss: 0.120104, bce_w_dice_loss: 0.366601, loss: 0.366601
# Epoch 88/99
# ----------
# train: bce_loss: 0.604759, dice_loss: 0.042394, bce_w_dice_loss: 0.323576, loss: 0.323576
# valid: bce_loss: 0.614367, dice_loss: 0.135738, bce_w_dice_loss: 0.375052, loss: 0.375052
# Epoch 89/99
# ----------
# train: bce_loss: 0.604527, dice_loss: 0.041141, bce_w_dice_loss: 0.322834, loss: 0.322834
# valid: bce_loss: 0.613401, dice_loss: 0.122082, bce_w_dice_loss: 0.367742, loss: 0.367742
# Epoch 90/99
# ----------
# train: bce_loss: 0.604721, dice_loss: 0.041983, bce_w_dice_loss: 0.323352, loss: 0.323352
# valid: bce_loss: 0.614272, dice_loss: 0.140058, bce_w_dice_loss: 0.377165, loss: 0.377165
# Epoch 91/99
# ----------
# train: bce_loss: 0.604530, dice_loss: 0.040857, bce_w_dice_loss: 0.322693, loss: 0.322693
# valid: bce_loss: 0.613176, dice_loss: 0.123675, bce_w_dice_loss: 0.368425, loss: 0.368425
# Epoch 92/99
# ----------
# train: bce_loss: 0.604607, dice_loss: 0.041328, bce_w_dice_loss: 0.322968, loss: 0.322968
# valid: bce_loss: 0.613447, dice_loss: 0.122181, bce_w_dice_loss: 0.367814, loss: 0.367814
# Epoch 93/99
# ----------
# train: bce_loss: 0.604557, dice_loss: 0.041049, bce_w_dice_loss: 0.322803, loss: 0.322803
# valid: bce_loss: 0.614422, dice_loss: 0.135298, bce_w_dice_loss: 0.374860, loss: 0.374860
# Epoch 94/99
# ----------
# train: bce_loss: 0.604733, dice_loss: 0.041750, bce_w_dice_loss: 0.323241, loss: 0.323241
# valid: bce_loss: 0.614256, dice_loss: 0.132506, bce_w_dice_loss: 0.373381, loss: 0.373381
# Epoch 95/99
# ----------
# train: bce_loss: 0.604702, dice_loss: 0.042772, bce_w_dice_loss: 0.323737, loss: 0.323737
# valid: bce_loss: 0.613092, dice_loss: 0.121127, bce_w_dice_loss: 0.367110, loss: 0.367110
# Epoch 96/99
# ----------
# train: bce_loss: 0.604725, dice_loss: 0.041819, bce_w_dice_loss: 0.323272, loss: 0.323272
# valid: bce_loss: 0.613281, dice_loss: 0.118219, bce_w_dice_loss: 0.365750, loss: 0.365750
# saving best model
# Epoch 97/99
# ----------
# train: bce_loss: 0.604735, dice_loss: 0.042173, bce_w_dice_loss: 0.323454, loss: 0.323454
# valid: bce_loss: 0.613257, dice_loss: 0.117335, bce_w_dice_loss: 0.365296, loss: 0.365296
# saving best model
# Epoch 98/99
# ----------
# train: bce_loss: 0.604844, dice_loss: 0.043121, bce_w_dice_loss: 0.323982, loss: 0.323982
# valid: bce_loss: 0.614246, dice_loss: 0.132310, bce_w_dice_loss: 0.373278, loss: 0.373278
# Epoch 99/99
# ----------
# train: bce_loss: 0.604742, dice_loss: 0.042317, bce_w_dice_loss: 0.323530, loss: 0.323530
# valid: bce_loss: 0.614160, dice_loss: 0.136043, bce_w_dice_loss: 0.375102, loss: 0.375102

# %% [markdown]
# ### Inference on Testset

# %%
import math

def inference(best_model_weights):
    model = UNet(in_channels=C, out_channels=O)
    model.to(device) 
    model.load_state_dict(best_model_weights)
    
    model.eval()
    
    x_test, y_test = next(iter(spine_loader['test']))
    x_test, y_test = x_test.float(), y_test.float()
    x_test, y_test = x_test.to(device), y_test.to(device)
    
    y_pred = model(x_test)
    y_pred = y_pred.data.cpu().numpy()
    
    print(y_pred.shape)
    
    fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(15,15))
    axs.imshow(x_test.data.cpu().numpy()[0, 0])

    fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15,15))
    axs[0].imshow(y_test.data.cpu().numpy()[0, 0])
    axs[1].imshow(y_test.data.cpu().numpy()[0, 1])
    axs[2].imshow(y_test.data.cpu().numpy()[0, 2])
    axs[3].imshow(y_test.data.cpu().numpy()[0, 3])

    fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15,15))
    axs[0].imshow(y_pred[0, 0])
    axs[1].imshow(y_pred[0, 1])
    axs[2].imshow(y_pred[0, 2])
    axs[3].imshow(y_pred[0, 3])
    
inference(best_model_weights)
# Out:
# (1, 4, 512, 512)

# %%
import torch
from torch.autograd import Variable
from torch.autograd import Function
import cv2
import sys
import numpy as np
import argparse

class FeatureExtractor():
    """ Class for extracting activations and 
    registering gradients from targetted intermediate layers """
    def __init__(self, model, target_layers):
        self.model = model
        self.target_layers = target_layers
        self.gradients = []

    def save_gradient(self, grad):
        self.gradients.append(grad)

    def __call__(self, x):
        outputs = []
        self.gradients = []
        for name, module in self.model._modules.items():
            x = module(x)
            if name in self.target_layers:
                x.register_hook(self.save_gradient)
                outputs += [x]
        return outputs, x

class ModelOutputs():
    """ Class for making a forward pass, and getting:
    1. The network output.
    2. Activations from intermeddiate targetted layers.
    3. Gradients from intermeddiate targetted layers. """
    def __init__(self, model, target_layers):
        self.model = model
        self.feature_extractor = FeatureExtractor(self.model.features, target_layers)

    def get_gradients(self):
        return self.feature_extractor.gradients

    def __call__(self, x):
        target_activations, output  = self.feature_extractor(x)
        output = output.view(output.size(0), -1)
        output = self.model.classifier(output)
        return target_activations, output

def preprocess_image(img):
    means=[0.485, 0.456, 0.406]
    stds=[0.229, 0.224, 0.225]

    preprocessed_img = img.copy()[: , :, ::-1]
    for i in range(3):
        preprocessed_img[:, :, i] = preprocessed_img[:, :, i] - means[i]
        preprocessed_img[:, :, i] = preprocessed_img[:, :, i] / stds[i]
    preprocessed_img = \
        np.ascontiguousarray(np.transpose(preprocessed_img, (2, 0, 1)))
    preprocessed_img = torch.from_numpy(preprocessed_img)
    preprocessed_img.unsqueeze_(0)
    input = Variable(preprocessed_img, requires_grad = True)
    return input

def show_cam_on_image(img, mask):
    heatmap = cv2.applyColorMap(np.uint8(255*mask), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    cam = heatmap + np.float32(img)
    cam = cam / np.max(cam)
    cv2.imwrite("cam.jpg", np.uint8(255 * cam))

class GradCam:
    def __init__(self, model, target_layer_names, use_cuda):
        self.model = model
        self.model.eval()
        self.cuda = use_cuda
        if self.cuda:
            self.model = model.cuda()

        self.extractor = ModelOutputs(self.model, target_layer_names)

    def forward(self, input):
        return self.model(input) 

    def __call__(self, input, index = None):
        if self.cuda:
            features, output = self.extractor(input.cuda())
        else:
            features, output = self.extractor(input)

        if index == None:
            index = np.argmax(output.cpu().data.numpy())

        one_hot = np.zeros((1, output.size()[-1]), dtype = np.float32)
        one_hot[0][index] = 1
        one_hot = Variable(torch.from_numpy(one_hot), requires_grad = True)
        if self.cuda:
            one_hot = torch.sum(one_hot.cuda() * output)
        else:
            one_hot = torch.sum(one_hot * output)

        self.model.features.zero_grad()
        self.model.classifier.zero_grad()
        one_hot.backward(retain_variables=True)

        grads_val = self.extractor.get_gradients()[-1].cpu().data.numpy()

        target = features[-1]
        target = target.cpu().data.numpy()[0, :]

        weights = np.mean(grads_val, axis = (2, 3))[0, :]
        cam = np.zeros(target.shape[1 : ], dtype = np.float32)

        for i, w in enumerate(weights):
            cam += w * target[i, :, :]

        cam = np.maximum(cam, 0)
        cam = cv2.resize(cam, (224, 224))
        cam = cam - np.min(cam)
        cam = cam / np.max(cam)
        return cam

class GuidedBackpropReLU(Function):

    def forward(self, input):
        positive_mask = (input > 0).type_as(input)
        output = torch.addcmul(torch.zeros(input.size()).type_as(input), input, positive_mask)
        self.save_for_backward(input, output)
        return output

    def backward(self, grad_output):
        input, output = self.saved_tensors
        grad_input = None

        positive_mask_1 = (input > 0).type_as(grad_output)
        positive_mask_2 = (grad_output > 0).type_as(grad_output)
        grad_input = torch.addcmul(torch.zeros(input.size()).type_as(input), torch.addcmul(torch.zeros(input.size()).type_as(input), grad_output, positive_mask_1), positive_mask_2)

        return grad_input

class GuidedBackpropReLUModel:
    def __init__(self, model, use_cuda):
        self.model = model
        self.model.eval()
        self.cuda = use_cuda
        if self.cuda:
            self.model = model.cuda()

        # replace ReLU with GuidedBackpropReLU
        for idx, module in self.model.features._modules.items():
            if module.__class__.__name__ == 'ReLU':
                self.model.features._modules[idx] = GuidedBackpropReLU()

    def forward(self, input):
        return self.model(input)

    def __call__(self, input, index = None):
        if self.cuda:
            output = self.forward(input.cuda())
        else:
            output = self.forward(input)

        if index == None:
            index = np.argmax(output.cpu().data.numpy())

        one_hot = np.zeros((1, output.size()[-1]), dtype = np.float32)
        one_hot[0][index] = 1
        one_hot = Variable(torch.from_numpy(one_hot), requires_grad = True)
        if self.cuda:
            one_hot = torch.sum(one_hot.cuda() * output)
        else:
            one_hot = torch.sum(one_hot * output)

        # self.model.features.zero_grad()
        # self.model.classifier.zero_grad()
        one_hot.backward(retain_variables=True)

        output = input.grad.cpu().data.numpy()
        output = output[0,:,:,:]

        return output

def main():
    """ python grad_cam.py <path_to_image>
    1. Loads an image with opencv.
    2. Preprocesses it for VGG19 and converts to a pytorch variable.
    3. Makes a forward pass to find the category index with the highest score,
    and computes intermediate activations.
    Makes the visualization. """

    # Can work with any model, but it assumes that the model has a 
    # feature method, and a classifier method,
    # as in the VGG models in torchvision.
    grad_cam = GradCam(model = models.vgg19(pretrained=True), \
                    target_layer_names = ["35"], use_cuda=True)

    img = cv2.imread(args.image_path, 1)
    img = np.float32(cv2.resize(img, (224, 224))) / 255
    input = preprocess_image(img)

    # If None, returns the map for the highest scoring category.
    # Otherwise, targets the requested index.
    target_index = None

    mask = grad_cam(input, target_index)

    show_cam_on_image(img, mask)

    gb_model = GuidedBackpropReLUModel(model = models.vgg19(pretrained=True), use_cuda=args.use_cuda)
    gb = gb_model(input, index=target_index)
    utils.save_image(torch.from_numpy(gb), 'gb.jpg')

    cam_mask = np.zeros(gb.shape)
    for i in range(0, gb.shape[0]):
        cam_mask[i, :, :] = mask

    cam_gb = np.multiply(cam_mask, gb)
    utils.save_image(torch.from_numpy(cam_gb), 'cam_gb.jpg')
# Out:
# usage: ipykernel_launcher.py [-h] [--use-cuda] [--image-path IMAGE_PATH]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\panacea\AppData\Roaming\jupyter\runtime\kernel-12d22552-1364-450c-a9dc-87de808ad41d.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\panacea\Anaconda3\envs\pytorch1.2_py3.7\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
